# %% [markdown]
# <a href="https://colab.research.google.com/github/DilshodovDilmurod/data_sience/blob/main/03_PANDAS_yakuniy_vazifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.columns= columns
df
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 223             Guyana      3.6765      9.5220    790.326   214969
# 224      French Guiana      3.6685      9.5015    306.448    83534
# 225           Suriname      3.6125      9.3564    591.800   163820
# 226          Australia      3.3526      8.6832  25788.215  7692024
# 227            Iceland      3.3335      8.6338    343.353   103000
# 228            Namibia      3.1338      8.1166   2587.344   825615
# 229     Western Sahara      2.3003      5.9577    611.875   266000
# 230           Mongolia      2.1286      5.5129   3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517      3.533    12173
# 232          Greenland      0.0263      0.0680     56.877  2166086

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df2 = df.iloc[[10,20, 100, 200]]
df2
# Out:
#           davlat  zichlik_km  zichlik_mi       aholi  maydoni
# rank
# 11    Bangladesh   1126.9465   2918.7915  166303.498   147570
# 21    San Marino    557.6557   1444.3284      34.017       61
# 101        Benin    110.5560    286.3401   12451.040   112622
# 201     Paraguay     17.7495     45.9712    7219.638   406752

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
# JAVOBNI SHUYERGA YOZING
countrys = ['uzbekistan', 'Hong-Kong', 'Antartica']
df['davlat'].isin(countrys)
# Out:
# rank
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# Name: davlat, Length: 232, dtype: bool

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
df1=df.set_index('davlat')
df1.sort_index()
# Out:
#                    zichlik_km  zichlik_mi         aholi  maydoni
# davlat
# Afghanistan           61.0757    158.1862  3.983543e+10   652230
# Albania               99.9351    258.8318  2.872933e+09    28748
# Algeria               18.7328     48.5179  4.461662e+10  2381741
# American Samoa       276.8844    717.1307  5.510000e+07      199
# Andorra              165.2885    428.0971  7.735500e+07      468
# ...                       ...         ...           ...      ...
# Wallis and Futuna     78.1268    202.3483  1.109400e+07      142
# Western Sahara         2.3003      5.9577  6.118750e+08   266000
# Yemen                 57.7509    149.5749  3.049064e+10   527968
# Zambia                25.1400     65.1125  1.892065e+10   752612
# Zimbabwe              38.6229    100.0333  1.509217e+10   390757
#
# [232 rows x 4 columns]

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
# JAVOBNI SHUYERGA YOZING
df1.loc[['Uzbekistan', 'Malaysia', 'South Korea', 'France'], ['aholi', 'maydoni']]
# Out:
#                  aholi  maydoni
# davlat
# Uzbekistan   33935.763   447400
# Malaysia     32776.194   330803
# South Korea  51305.186   100210
# France       65426.179   551695

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
# JAVOBNI SHUYERGA YOZ
df1['aholi']*=1000
df1
# Out:
#                   zichlik_km  zichlik_mi         aholi  maydoni
# davlat
# Macau             21946.4667  56841.3487  6.583940e+11       30
# Monaco            19755.5000  51166.7450  3.951100e+10        2
# Singapore          8305.1915  21510.4461  5.896686e+12      710
# Hong Kong          6841.3134  17719.0017  7.552810e+12     1104
# Gibraltar          5616.3333  14546.3033  3.369800e+10        6
# ...                      ...         ...           ...      ...
# Namibia               3.1338      8.1166  2.587344e+12   825615
# Western Sahara        2.3003      5.9577  6.118750e+11   266000
# Mongolia              2.1286      5.5129  3.329289e+12  1564110
# Falkland Islands      0.2902      0.7517  3.533000e+09    12173
# Greenland             0.0263      0.0680  5.687700e+10  2166086
#
# [232 rows x 4 columns]

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df1.sort_values(by = 'aholi', ascending=False).tail(10)
# Out:
#                            zichlik_km  zichlik_mi         aholi  maydoni
# davlat
# Tuvalu                       458.8846   1188.5112  1.193100e+10       26
# Wallis and Futuna             78.1268    202.3483  1.109400e+10      142
# Nauru                        517.9048   1341.3733  1.087600e+10       21
# Saint Barthelemy             471.7619   1221.8633  9.907000e+09       21
# Saint Pierre and Miquelon     23.8264     61.7105  5.766000e+09      242
# Montserrat                    48.7941    126.3768  4.977000e+09      102
# Falkland Islands               0.2902      0.7517  3.533000e+09    12173
# Niue                           6.2269     16.1277  1.619000e+09      260
# Tokelau                      114.4167    296.3392  1.373000e+09       12
# Vatican City                 800.0000   2072.0000  8.000000e+08        1

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
# JAVOBNI SHUYERGA YOZING
df1['rank'] = df1['maydoni'].rank(method='min')
df1.sort_index()
# Out:
#                    zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  3.983543e+13   652230  192.0
# Albania               99.9351    258.8318  2.872933e+12    28748   89.0
# Algeria               18.7328     48.5179  4.461662e+13  2381741  223.0
# American Samoa       276.8844    717.1307  5.510000e+10      199   20.0
# Andorra              165.2885    428.0971  7.735500e+10      468   38.0
# ...                       ...         ...           ...      ...    ...
# Wallis and Futuna     78.1268    202.3483  1.109400e+10      142   15.0
# Western Sahara         2.3003      5.9577  6.118750e+11   266000  155.0
# Yemen                 57.7509    149.5749  3.049064e+13   527968  183.0
# Zambia                25.1400     65.1125  1.892065e+13   752612  194.0
# Zimbabwe              38.6229    100.0333  1.509217e+13   390757  172.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230  192.0
# Albania               99.9351    258.8318   2872933.0    28748   89.0
# Algeria               18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa       276.8844    717.1307     55100.0      199   20.0
# Andorra              165.2885    428.0971     77355.0      468   38.0
# ...                       ...         ...         ...      ...    ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142   15.0
# Western Sahara         2.3003      5.9577    611875.0   266000  155.0
# Yemen                 57.7509    149.5749  30490640.0   527968  183.0
# Zambia                25.1400     65.1125  18920651.0   752612  194.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757  172.0
#
# [232 rows x 5 columns]

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df1.loc[['Uzbekistan', 'United Kingdom', 'Indonesia']]
# Out:
#                 zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Uzbekistan         75.8511    196.4542  3.393576e+13   447400  176.0
# United Kingdom    280.8033    727.2805  6.820712e+13   242900  153.0
# Indonesia         145.1046    375.8210  2.763618e+14  1904569  218.0

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                zichlik_km  zichlik_mi        aholi  maydoni   rank
# davlat
# Turkmenistan      12.5342     32.4635    6117924.0   488100  180.0
# United States     35.5200     91.9968  332915073.0  9372610  229.0
# Vietnam          296.3927    767.6572   98168833.0   331212  166.0

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
# JAVOBNI SHUYERGA YOZING
df1.sort_index()
# Out:
#                    zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  3.983543e+13   652230  192.0
# Albania               99.9351    258.8318  2.872933e+12    28748   89.0
# Algeria               18.7328     48.5179  4.461662e+13  2381741  223.0
# American Samoa       276.8844    717.1307  5.510000e+10      199   20.0
# Andorra              165.2885    428.0971  7.735500e+10      468   38.0
# ...                       ...         ...           ...      ...    ...
# Wallis and Futuna     78.1268    202.3483  1.109400e+10      142   15.0
# Western Sahara         2.3003      5.9577  6.118750e+11   266000  155.0
# Yemen                 57.7509    149.5749  3.049064e+13   527968  183.0
# Zambia                25.1400     65.1125  1.892065e+13   752612  194.0
# Zimbabwe              38.6229    100.0333  1.509217e+13   390757  172.0
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230  192.0
# Albania            99.9351    258.8318   2872933.0    28748   89.0
# Algeria            18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa    276.8844    717.1307     55100.0      199   20.0
# Andorra           165.2885    428.0971     77355.0      468   38.0

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df1.iloc[[10,50, 100, 200]]
# Out:
#                      zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Bangladesh            1126.9465   2918.7915  1.663035e+14   147570  139.0
# Trinidad and Tobago    273.5624    708.5266  1.403375e+12     5130   61.0
# Benin                  110.5560    286.3401  1.245104e+13   112622  131.0
# Paraguay                17.7495     45.9712  7.219638e+12   406752  173.0

# %%
#@title O'xshash natija (boshqa qatorlar uchun)
# Out:
#                               zichlik_km  zichlik_mi     aholi  maydoni  rank
# davlat
# Belize                           17.6310     45.6643  404914.0    22966  82.0
# French Polynesia                 67.8018    175.6066  282530.0     4167  60.0
# Guadeloupe                      245.7125    636.3955  400020.0     1628  53.0
# United States Virgin Islands    300.3631    777.9405  104226.0      347  29.0

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
df1.loc[['Malaysia','Nigeria', 'Nepal', 'Italy'], 'aholi']
# Out:
# davlat
# Malaysia    3.277619e+13
# Nigeria     2.114007e+14
# Nepal       2.967492e+13
# Italy       6.036748e+13
# Name: aholi, dtype: float64

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
# Out:
# 33935763.0
